# %%
#Import relevant packages

import pandas as pd
import re
import numpy as np

#Script that will clean data for the Wellcome problem set and find the mean median and standard deviation of the cost 
#of each journal.

def wellcome_clean():
    wellcome = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding = "ISO-8859-1")
    
    #Rename columns
    
    wellcome.columns = ['ID','Publisher','Journal','Title','Cost']
    
    #Drop unecessary columns
    
    wellcome2 = wellcome.drop(['ID','Publisher'], axis=1)

    #Get a first look at the data
    
    print(wellcome2.describe())
    print("")
    
    #Get unique journal title count
    
    j = wellcome2['Journal'].value_counts()
    print('Below is the current number of unique journal values:')
    print(j.sum())
    print("")
    
    #Remove pound sign from cost column and add that list in as a new column
    
    x = wellcome2['Cost'].str.extract('([\d]+.[\d]+)', expand=True)[0]
    wellcome2['Pounds'] = x.astype(float)
    
    #Make all journal entries lowercase
    
    wellcome2['lc_journal'] = wellcome2['Journal'].str.lower()
    
    #Clear all journals of blank space
    
    wellcome2['stripjournal'] = wellcome2['lc_journal'].str.strip()
    
    #Remove Null and NA values from Dataframe
    
    wellcome2.dropna()
    
    #Count journals again to see if we lost any data
    j2 = wellcome2['Journal'].value_counts()
    print('Below is the new number of unique journal values:')
    print(j2.sum())
    print("")
    
    #Group by journal and determine the five most common journals and count their articles 
    groupedbyjournal = wellcome2.groupby('stripjournal').agg('count').reset_index().sort_values(['Pounds'], ascending=[0]).head(5)
    print(groupedbyjournal)
    
    #Get the mean median and standard deviation for each of the journals
    print(wellcome2.groupby(['stripjournal']).mean().reset_index().sort_values(['Pounds'],ascending=False))
    print(wellcome2.groupby(['stripjournal']).median().reset_index().sort_values(['Pounds'],ascending=False))
    print(wellcome2.groupby(['stripjournal']).std().reset_index().sort_values(['Pounds'],ascending=False).dropna())
    
    
wellcome_clean()
# Out:
#          Journal                                              Title      Cost
# count       2126                                               2127      2127
# unique       984                                               2126      1402
# top     PLoS One  Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq          92                                                  2        94
#
# Below is the current number of unique journal values:
# 2126
#
# Below is the new number of unique journal values:
# 2126
#
#                         stripjournal  Journal  Title  Cost  Pounds  lc_journal
# 744                         plos one      190    190   190     190         190
# 501  journal of biological chemistry       53     53    53      53          53
# 677                       neuroimage       29     29    29      29          29
# 699           nucleic acids research       26     26    26      26          26
# 738                    plos genetics       24     24    24      24          24
#                                           stripjournal         Pounds
# 786                               qualitative research  999999.000000
# 322                         experimental cell research  999999.000000
# 847              the journal of cognitive neuroscience  999999.000000
# 390                        hbm jnl human brain mapping  999999.000000
# 752                                     pone-d12-17947  999999.000000
# 132                                      bmc genomics.  999999.000000
# 572                      journal of paediatric urology  999999.000000
# 638                 molecluar & cellular endocrinology  999999.000000
# 329               expert reviews in molecular medicine  999999.000000
# 343                             frontiers in cognition  999999.000000
# 712                            oxford university press  999999.000000
# 747                               pmedicine-d-12-03130  999999.000000
# 381                               genetics in medicine  501499.500000
# 885                            veterinary parasitology  501243.585000
# 873                            trends in neurosciences  501212.980000
# 891                                    vision research  500727.590000
# 648                                     molecular cell  402355.042000
# 281                                       embo reports  335413.000000
# 590     journal of the international african institute  334689.000000
# 474                           jnl biological chemistry  333805.013333
# 874                             trends in parasitology  251692.990000
# 183                                               cell  202537.214000
# 559                          journal of neurochemistry  201664.874000
# 404                      history of the human sciences  201535.800000
# 403                                        hippocampus  201341.816000
# 875                                             trials  200960.180000
# 748                                               pnas  167303.490000
# 204                                    cerebral cortex  144666.285714
# 506                            journal of cell science  126854.875000
# 575                              journal of physiology  126783.231250
# ..                                                 ...            ...
# 10                          acta dermato venereologica     653.960000
# 750                                           pnas usa     651.580000
# 317  evidence, ethos and experiment: the anthropolo...     651.250000
# 637                                          mol pharm     649.330000
# 452              international journal of rheumatology     626.000000
# 359                         frontiers in neurorobotics     625.200000
# 573                   journal of parasitology research     623.950000
# 757  proceddings of the national academy of science...     619.830000
# 78                                           autophagy     601.100000
# 538                    journal of historical geography     596.460000
# 391                                             health     551.270000
# 860                                       theranostics     543.290000
# 604                 journal of visualized experiements     517.500000
# 290                                         epigentics     508.660000
# 289                                        epigenetics     490.485000
# 796                                        rna biology     490.123333
# 694                                     neuroscientist     480.930000
# 344                     frontiers in cognitive science     434.700000
# 464                                       j infect dis     378.780000
# 389              haematologica/the haematology journal     378.700000
# 350                              frontiers in genetics     346.250000
# 730                    physics in biology and medicine     340.000000
# 184                        cell adhesion and migration     321.460000
# 293                             essays in biochemistry     270.000000
# 445        international journal of financial research     187.030000
# 563  journal of neurology & translational neuroscience     159.910000
# 207                                           channels     159.740000
# 503       journal of biomedical graphics and computing     135.290000
# 51                      american society for nutrition      45.940000
# 887                                veterinary research       9.930000
#
# [894 rows x 2 columns]
#                                           stripjournal      Pounds
# 572                      journal of paediatric urology  999999.000
# 132                                      bmc genomics.  999999.000
# 343                             frontiers in cognition  999999.000
# 747                               pmedicine-d-12-03130  999999.000
# 752                                     pone-d12-17947  999999.000
# 390                        hbm jnl human brain mapping  999999.000
# 322                         experimental cell research  999999.000
# 786                               qualitative research  999999.000
# 638                 molecluar & cellular endocrinology  999999.000
# 712                            oxford university press  999999.000
# 847              the journal of cognitive neuroscience  999999.000
# 329               expert reviews in molecular medicine  999999.000
# 381                               genetics in medicine  501499.500
# 885                            veterinary parasitology  501243.585
# 873                            trends in neurosciences  501212.980
# 891                                    vision research  500727.590
# 782                              public service review    6000.000
# 858                               the lancet neurology    5040.000
# 857                                         the lancet    4554.010
# 192                                cell host & microbe    4226.040
# 243                                         curr biol.    4151.770
# 648                                     molecular cell    4148.390
# 194                                       cell journal    4041.050
# 183                                               cell    3948.420
# 418                                           immunity    3934.750
# 684                                             neuron    3918.420
# 195                                    cell metabolism    3904.460
# 830                                          structure    3895.640
# 196                          cell press - cell reports    3884.400
# 266                                 developmental cell    3861.420
# ..                                                 ...         ...
# 750                                           pnas usa     651.580
# 317  evidence, ethos and experiment: the anthropolo...     651.250
# 637                                          mol pharm     649.330
# 452              international journal of rheumatology     626.000
# 359                         frontiers in neurorobotics     625.200
# 573                   journal of parasitology research     623.950
# 757  proceddings of the national academy of science...     619.830
# 762  proceedings of the national academy of science...     601.700
# 78                                           autophagy     601.100
# 538                    journal of historical geography     596.460
# 391                                             health     551.270
# 860                                       theranostics     543.290
# 604                 journal of visualized experiements     517.500
# 290                                         epigentics     508.660
# 796                                        rna biology     494.960
# 289                                        epigenetics     490.485
# 694                                     neuroscientist     480.930
# 344                     frontiers in cognitive science     434.700
# 464                                       j infect dis     378.780
# 389              haematologica/the haematology journal     378.700
# 350                              frontiers in genetics     346.250
# 730                    physics in biology and medicine     340.000
# 184                        cell adhesion and migration     321.460
# 293                             essays in biochemistry     270.000
# 445        international journal of financial research     187.030
# 563  journal of neurology & translational neuroscience     159.910
# 207                                           channels     159.740
# 503       journal of biomedical graphics and computing     135.290
# 51                      american society for nutrition      45.940
# 887                                veterinary research       9.930
#
# [894 rows x 2 columns]
#                                           stripjournal         Pounds
# 891                                    vision research  706076.399327
# 873                            trends in neurosciences  705389.954206
# 885                            veterinary parasitology  705346.672200
# 381                               genetics in medicine  704984.753736
# 474                           jnl biological chemistry  576941.008959
# 590     journal of the international african institute  576175.361392
# 281                                       embo reports  575548.358999
# 648                                     molecular cell  545571.816173
# 874                             trends in parasitology  498870.709384
# 875                                             trials  446676.288070
# 403                                        hippocampus  446463.084753
# 404                      history of the human sciences  446354.498183
# 559                          journal of neurochemistry  446282.371661
# 183                                               cell  445796.050484
# 748                                               pnas  407935.852638
# 204                                    cerebral cortex  377166.376897
# 575                              journal of physiology  352832.623849
# 506                            journal of cell science  352803.671489
# 746                                            plosone  333043.204396
# 737                         plos computational biology  332815.641275
# 745                                     plos pathogens  281885.544090
# 738                                      plos genetics  281865.707794
# 410                           human molecular genetics  228947.274919
# 663                              nature communications  228698.044027
# 744                                           plos one  189009.511974
# 501                    journal of biological chemistry  137165.488398
# 657                                 movement disorders   51414.460186
# 608                                             lancet    2801.309580
# 372                                   gastroenterology    1407.085926
# 777                                      public health    1369.828470
# ..                                                 ...            ...
# 340               frontiers in behavioral neuroscience       0.000000
# 837                            the biochemical journal       0.000000
# 754                       postgraduate medical journal       0.000000
# 58             angewandte chemie international edition       0.000000
# 111                                       biology open       0.000000
# 317  evidence, ethos and experiment: the anthropolo...       0.000000
# 307                 european journal of human genetics       0.000000
# 72                            arthritis and rheumatism       0.000000
# 838                  the british journal of psychiatry       0.000000
# 607                               kidney international       0.000000
# 30             alimentrary pharmacology & therapeutics       0.000000
# 564    journal of neurology, neurosurgery & psychiatry       0.000000
# 257                                  dev world bioeth.       0.000000
# 779                            public health nutrition       0.000000
# 279                                       embo journal       0.000000
# 565  journal of neurology, neurosurgery and psychiatry       0.000000
# 794                                       rheumatology       0.000000
# 83                      behaviour research and therapy       0.000000
# 524                    journal of depression & anxiety       0.000000
# 799                             schizophrenia research       0.000000
# 164                          british journal of cancer       0.000000
# 803                                 scientific reports       0.000000
# 258                                  dev. world bioeth       0.000000
# 205                             cerebral cortex online       0.000000
# 548                          journal of medical ethics       0.000000
# 815        social psychiatry and psychiatric epidemiol       0.000000
# 592           journal of the national cancer institute       0.000000
# 221                                    chronic illness       0.000000
# 666                         neglected tropical disease       0.000000
# 545               journal of investigative dermatology       0.000000
#
# [326 rows x 2 columns]
