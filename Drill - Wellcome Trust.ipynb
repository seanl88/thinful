# %% [raw]
# import pandas as pd
# import re

# %%
wellcome = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding = "ISO-8859-1")
wellcome.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
wellcome.columns = ['ID','Publisher','Journal','Title','Cost']
wellcome.describe()
# Out:
#           ID Publisher   Journal  \
# count   1928      2127      2126
# unique  1880       299       984
# top        -  Elsevier  PLoS One
# freq       7       387        92
#
#                                                     Title      Cost
# count                                                2127      2127
# unique                                               2126      1402
# top     Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq                                                    2        94

# %%
x = wellcome['Cost'].str.extract( '([\d]+.[\d]+)', expand=True)[0]
x.head()
# Out:
# 0       0.00
# 1    2381.04
# 2     642.56
# 3     669.64
# 4     685.88
# Name: 0, dtype: object

# %%
wellcome['Pounds'] = x.astype(float)

# %%
wellcome.head(10)
# Out:
#                       ID Publisher                         Journal  \
# 0                    NaN       NaN          Psychological Medicine
# 1             PMC3679557   3679557               Biomacromolecules
# 2  23043264  PMC3506128    3506128                      J Med Chem
# 3    23438330 PMC3646402   3646402                      J Med Chem
# 4   23438216 PMC3601604    3601604                      J Org Chem
# 5             PMC3579457   3579457  Journal of Medicinal Chemistry
# 6             PMC3709265   3709265    Journal of Proteome Research
# 7   23057412 PMC3495574    3495574                       Mol Pharm
# 8      PMCID: PMC3780468   3780468            ACS Chemical Biology
# 9      PMCID: PMC3621575   3621575            ACS Chemical Biology
#
#                                                Title      Cost      PMC  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00      NaN
# 1  Structural characterization of a Model Gram-ne...  £2381.04  3679557
# ...

# %%
wellcome['Publisher'] = wellcome['ID'].str.extract( '(PMC)([\d]+)', expand=True)[1]

# %%
wellcome['PMC'] = wellcome['ID'].str.extract( '(PMC)([\d]+)', expand=True)[1]
wellcome.head(10)
# Out:
#                       ID Publisher                         Journal  \
# 0                    NaN       NaN          Psychological Medicine
# 1             PMC3679557   3679557               Biomacromolecules
# 2  23043264  PMC3506128    3506128                      J Med Chem
# 3    23438330 PMC3646402   3646402                      J Med Chem
# 4   23438216 PMC3601604    3601604                      J Org Chem
# 5             PMC3579457   3579457  Journal of Medicinal Chemistry
# 6             PMC3709265   3709265    Journal of Proteome Research
# 7   23057412 PMC3495574    3495574                       Mol Pharm
# 8      PMCID: PMC3780468   3780468            ACS Chemical Biology
# 9      PMCID: PMC3621575   3621575            ACS Chemical Biology
#
#                                                Title      Cost      PMC  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00      NaN
# 1  Structural characterization of a Model Gram-ne...  £2381.04  3679557
# ...

# %%
splitfirst = wellcome['ID'].str.split('PMC', expand=True)
splitfirst.head(10)
# Out:
#             0         1        2
# 0         NaN      None     None
# 1               3679557     None
# 2  23043264    3506128      None
# 3   23438330    3646402     None
# 4   23438216   3601604      None
# 5               3579457     None
# 6               3709265     None
# 7   23057412   3495574      None
# 8                  ID:   3780468
# 9                  ID:   3621575

# %%
journal = wellcome.groupby('Journal').agg('count').reset_index()
journal.head(5)
# Out:
#                      Journal  ID  Publisher  Title  Cost  PMC  ljournal  \
# 0       ACS Chemical Biology   4          4      5     5    4         5
# 1  ACS Chemical Neuroscience   1          1      1     1    1         1
# 2                   ACS NANO   1          0      1     1    0         1
# 3                   ACS Nano   1          0      1     1    0         1
# 4                     ACTA F   1          1      1     1    1         1
#
#    stripjournal  Pound  Pounds
# 0             5      5       5
# 1             1      1       1
# 2             1      1       1
# 3             1      1       1
# 4             1      1       1

# %%
wellcome['ljournal'] = wellcome['Journal'].str.lower()

# %%
wellcome['stripjournal'] = wellcome['ljournal'].str.strip()
wellcome.head()
# Out:
#                       ID Publisher                 Journal  \
# 0                    NaN       NaN  Psychological Medicine
# 1             PMC3679557   3679557       Biomacromolecules
# 2  23043264  PMC3506128    3506128              J Med Chem
# 3    23438330 PMC3646402   3646402              J Med Chem
# 4   23438216 PMC3601604    3601604              J Org Chem
#
#                                                Title      Cost      PMC  \
# 0  Reduced parahippocampal cortical thickness in ...     £0.00      NaN
# 1  Structural characterization of a Model Gram-ne...  £2381.04  3679557
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56  3506128
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64  3646402
# 4  Regioselective opening of myo-inositol orthoes...   £685.88  3601604
#
#                  ljournal            stripjournal    Pound   Pounds
# 0  psychological medicine  psychological medicine     0.00     0.00
# ...

# %%
groupedbyjournal = wellcome.groupby('stripjournal').agg('count').reset_index()
groupedbyjournal.sort_values(['Publisher'], ascending=[0]).head(5)
# Out:
#                         stripjournal   ID  Publisher  Journal  Title  Cost  \
# 744                         plos one  188        137      190    190   190
# 501  journal of biological chemistry   52         39       53     53    53
# 677                       neuroimage   28         25       29     29    29
# 738                    plos genetics   23         20       24     24    24
# 745                   plos pathogens   24         17       24     24    24
#
#      PMC  ljournal  Pound  Pounds
# 744  137       190    190     190
# 501   39        53     53      53
# 677   25        29     29      29
# 738   20        24     24      24
# 745   17        24     24      24

# %%
wellcome.groupby(['stripjournal']).mean().reset_index()
# Out:
#                                           stripjournal          Pound  \
# 0                   academy of nutrition and dietetics    2379.540000
# 1                                 acs chemical biology    1418.186000
# 2                            acs chemical neuroscience    1186.800000
# 3                                             acs nano     668.140000
# 4    acta crystallographica section d,  biological ...     771.420000
# 5    acta crystallographica section d: biological c...     773.740000
# 6    acta crystallographica section f: structural b...     796.635000
# 7                    acta crystallographica, section d     757.180000
# 8                               acta crystallography d     774.190000
# 9                                               acta d     750.160000
# 10                          acta dermato venereologica     653.960000
# 11                                  acta diabetologica    2336.280000
# ...

# %%
wellcome.groupby(['stripjournal']).median().reset_index()
# Out:
#                                           stripjournal       Pound  \
# 0                   academy of nutrition and dietetics    2379.540
# 1                                 acs chemical biology    1294.590
# 2                            acs chemical neuroscience    1186.800
# 3                                             acs nano     668.140
# 4    acta crystallographica section d,  biological ...     771.420
# 5    acta crystallographica section d: biological c...     773.740
# 6    acta crystallographica section f: structural b...     796.635
# 7                    acta crystallographica, section d     757.180
# 8                               acta crystallography d     774.190
# 9                                               acta d     750.160
# 10                          acta dermato venereologica     653.960
# 11                                  acta diabetologica    2336.280
# 12                                              acta f     754.900
# ...

# %%
wellcome.groupby(['stripjournal']).std().reset_index()
# Out:
#                                           stripjournal          Pound  \
# 0                   academy of nutrition and dietetics            NaN
# 1                                 acs chemical biology     507.309560
# 2                            acs chemical neuroscience            NaN
# 3                                             acs nano      35.708892
# 4    acta crystallographica section d,  biological ...            NaN
# 5    acta crystallographica section d: biological c...            NaN
# 6    acta crystallographica section f: structural b...      15.605847
# 7                    acta crystallographica, section d            NaN
# 8                               acta crystallography d            NaN
# 9                                               acta d            NaN
# 10                          acta dermato venereologica            NaN
# 11                                  acta diabetologica            NaN
# ...
